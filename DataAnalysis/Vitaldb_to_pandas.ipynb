# %%
import pandas as pd
df_cases = pd.read_csv("https://api.vitaldb.net/cases")  # clinical information
df_trks = pd.read_csv("https://api.vitaldb.net/trks")  # track list
df_labs = pd.read_csv('https://api.vitaldb.net/labs')  # laboratory results

# %%
vd = df_cases[['age','sex','height','weight','bmi']].head(51)
vd
# Out:
#      age sex  height  weight   bmi
# 0   77.0   M   160.2   67.50  26.3
# 1   54.0   M   167.3   54.80  19.6
# 2   62.0   M   169.1   69.70  24.4
# 3   74.0   M   160.6   53.00  20.5
# 4   66.0   M   171.0   59.70  20.4
# 5   78.0   F   150.0   54.60  24.3
# 6   52.0   F   167.7   62.30  22.2
# 7   81.0   F   156.7   67.25  27.4
# 8   32.0   F   157.9   50.90  20.4
# 9   72.0   M   162.5   62.75  23.8
# 10  56.0   M   175.4   81.45  26.5
# 11  46.0   F   169.2   81.40  28.4
# 12  67.0   F   153.0   64.90  27.7
# 13  23.0   M   177.9   80.00  25.3
# 14  56.0   F   158.0   48.30  19.3
# 15  57.0   M   162.3   68.90  26.2
# 16  85.0   M   164.2   53.00  19.7
# 17  77.0   F   155.0   56.90  23.7
# 18  74.0   M   171.3   66.20  22.6
# 19  75.0   M   173.6   61.30  20.3
# 20  69.0   F   155.1   61.60  25.6
# 21  53.0   F   162.0   54.60  20.8
# 22  69.0   F   139.4   47.80  24.6
# 23  57.0   M   161.8   65.00  24.8
# 24  66.0   M   169.7   80.20  27.8
# 25  64.0   M   169.7   62.60  21.7
# 26  50.0   F   143.2   43.35  21.1
# 27  67.0   F   148.9   49.90  22.5
# 28  53.0   F   156.1   57.40  23.6
# 29  59.0   F   166.4   57.60  20.8
# 30  58.0   M   162.8   53.80  20.3
# 31  74.0   M   169.4   71.90  25.1
# 32  47.0   M   171.8   88.00  29.8
# 33  69.0   F   150.5   66.60  29.4
# 34  58.0   F   155.2   50.40  20.9
# 35  38.0   F   155.6   50.20  20.7
# 36  56.0   M   180.5   82.75  25.4
# 37  66.0   M   170.1   72.30  25.0
# 38  68.0   M   162.5   64.70  24.5
# 39  41.0   F   160.1   83.20  32.5
# 40  45.0   M   175.0   78.70  25.7
# 41  72.0   M   166.7   72.50  26.1
# 42  64.0   M   172.4   52.90  17.8
# 43  56.0   M   175.8   59.90  19.4
# 44  78.0   F   147.9   50.00  22.9
# 45  75.0   F   150.7   53.75  23.7
# 46  73.0   M   167.1   48.70  17.4
# 47  58.0   F   160.3   56.20  21.9
# 48  68.0   M   165.8   67.50  24.6
# 49  47.0   F   158.1   51.60  20.6
# 50  36.0   F   165.5   55.30  20.2
