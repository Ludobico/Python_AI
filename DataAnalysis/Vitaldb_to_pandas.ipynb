# %%
import pandas as pd
df_cases = pd.read_csv("https://api.vitaldb.net/cases")  # clinical information
df_trks = pd.read_csv("https://api.vitaldb.net/trks")  # track list
df_labs = pd.read_csv('https://api.vitaldb.net/labs')  # laboratory results

# %%
vd = df_cases[['age','sex','height','weight','bmi']].sample(50)
vd
# Out:
#        age sex  height  weight   bmi
# 3415  76.0   F   144.7   44.00  21.0
# 1348  78.0   F   146.5   51.40  23.9
# 5979  61.0   F   154.5   52.80  22.1
# 2210  55.0   F   160.0   52.60  20.5
# 507   52.0   F   160.9   55.90  21.6
# 1193  56.0   M   180.6   66.40  20.4
# 5872  74.0   M   173.7   75.20  24.9
# 1856  59.0   M   161.4   63.70  24.5
# 370   50.0   M   173.0   83.80  28.0
# 5331  44.0   F   157.6   45.80  18.4
# 824   51.0   F   159.0   49.00  19.4
# 2458  26.0   M   170.0   43.20  14.9
# 513   75.0   F   147.8   56.20  25.7
# 2436  70.0   M   159.3   62.30  24.6
# 2477  51.0   F   160.1   54.40  21.2
# 5637  75.0   M   169.8   65.75  22.8
# 3511  78.0   F   150.2   49.30  21.9
# 2460  47.0   F   156.4   52.80  21.6
# 2959  48.0   M   187.0   74.00  21.2
# 90    48.0   F   164.7   53.90  19.9
# 1923  44.0   F   156.1   51.25  21.0
# 1467  69.0   M   160.4   57.50  22.3
# 4831  86.0   M   164.0   62.60  23.3
# 2439  67.0   M   162.1   71.20  27.1
# 1157  42.0   F   159.1   46.20  18.3
# 5250  22.0   M   181.4   79.70  24.2
# 5016  82.0   M   168.3   64.05  22.6
# 5446  44.0   F   157.7   59.00  23.7
# 1063  55.0   F   150.6   50.65  22.3
# 4747  12.0   F   147.5   33.55  15.4
# 471   64.0   M   171.5   57.70  19.6
# 798   54.0   F   155.9   51.50  21.2
# 808   66.0   M   167.5   58.60  20.9
# 401   30.0   F   153.7   54.90  23.2
# 5588  50.0   M   166.9   60.60  21.8
# 5748  80.0   F   143.7   52.50  25.4
# 1305  36.0   M   177.7   72.80  23.1
# 3145  72.0   M   163.2   64.20  24.1
# 2587  80.0   F   159.6   80.20  31.5
# 3341  49.0   F   161.7   66.10  25.3
# 5021  28.0   F   165.2   70.35  25.8
# 1519  40.0   F   159.1   52.80  20.9
# 187   74.0   M   161.9   73.50  28.0
# 4637  62.0   M   167.0   67.75  24.3
# 4716  48.0   F   165.0   56.35  20.7
# 4217  73.0   F   153.9   62.55  26.4
# 2026  73.0   M   163.0   51.70  19.5
# 1447  12.0   F   147.5   33.55  15.4
# 603   43.0   F   158.9   63.30  25.1
# 4110  57.0   M   164.3   49.15  18.2
