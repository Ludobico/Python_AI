# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('./classification220926/train.csv')
dftest = pd.read_csv('./classification220926/test.csv')

x = df.iloc[:,:-1]
x1_test = dftest.iloc[:, :]
y = df.loc[:,['income']]
# y1_test = dftest.loc[:,['income']]

# %%
x.drop(['no', 'education','fnlwgt','native-country'], axis=1, inplace=True)
x1_test.drop(['no', 'education','fnlwgt','native-country','hours-per-week'],axis=1, inplace=True)

droppre = x[x['education-num'] == 1]

# %%
x.value_counts('workclass')
# Out:
# workclass
#  Private             20410
#  Self-emp-not-inc     2305
#  Local-gov            1868
#  ?                    1663
#  State-gov            1201
#  Self-emp-inc          987
#  Federal-gov           854
#  Without-pay            12
#  Never-worked            5
# dtype: int64

# %%
import re


# x.replace({'marital-status' : {'Never-married':0,'Separated':1,'Widowed':2,'Married-spouse-absent':3
#                                ,'Divorced':4,'Married-AF-spouse':5,'Married-civ-spouse':6}},inplace=True,regex=True)


# x.replace({'occupation': {'Priv-house-serv':0,'Other-service':1,'Handlers-cleaners':2,'\?':3,
#                           'Farming-fishing':4,'Machine-op-inspct':5,'Adm-clerical':6,
#                           'Transport-moving':7,'Craft-repair':8,'Sales':9,
#                           'Tech-support':10,'Armed-Forces':11,'Protective-serv':12,
#                           'Prof-specialty':13,'Exec-managerial':14}},inplace=True,regex=True)

# x.replace({'relationship':{'Own-child':0,'Other-relative':1,'Unmarried':2,'Not-in-family':3,
#            'Husband':2,'Wife':2}},inplace=True,regex=True)

# x.replace({'workclass':{'Never-worked':0,'Without-pay':1,'\?':2,'Private':3,'State-gov':4,'Self-emp-not-inc':5,
#                         'Local-gov':6,'Federal-gov':7,'Self-emp-inc':8}},inplace=True,regex=True)

# x.replace({'race':{'Other':0,'Black':1,'Amer-Indian-Eskimo':2,'Asian-Pac-Islander':3,'White':4}},inplace=True,regex=True)

x.replace({'marital-status' : {'Never-married':0,'Separated':0,'Widowed':0,'Married-spouse-absent':0
                               ,'Divorced':1,'Married-AF-spouse':4,'Married-civ-spouse':4}},inplace=True,regex=True)


x.replace({'occupation': {'Priv-house-serv':0,'Other-service':0,'Handlers-cleaners':0,'\?':1,
                          'Farming-fishing':1,'Machine-op-inspct':1,'Adm-clerical':1,
                          'Transport-moving':2,'Craft-repair':2,'Sales':3,
                          'Tech-support':3,'Armed-Forces':3,'Protective-serv':3,
                          'Prof-specialty':4,'Exec-managerial':4}},inplace=True,regex=True)

x.replace({'relationship':{'Own-child':0,'Other-relative':0,'Unmarried':0,'Not-in-family':1,
           'Husband':4,'Wife':4}},inplace=True,regex=True)

x.replace({'workclass':{'Never-worked':0,'Without-pay':0,'\?':1,'Private':2,'State-gov':3,'Self-emp-not-inc':3,
                        'Local-gov':3,'Federal-gov':4,'Self-emp-inc':5}},inplace=True,regex=True)

# x.replace({'race':{'Other':1,'Black':1,'Amer-Indian-Eskimo':1,'Asian-Pac-Islander':2,'White':2}},inplace=True,regex=True)



# x1_test.replace({'marital-status' : {'Never-married':0,'Separated':0,'Widowed':0,'Married-spouse-absent':0
#                                ,'Divorced':1,'Married-AF-spouse':4,'Married-civ-spouse':4}},inplace=True,regex=True)


# x1_test.replace({'occupation': {'Priv-house-serv':0,'Other-service':0,'Handlers-cleaners':0,'\?':1,
#                           'Farming-fishing':1,'Machine-op-inspct':1,'Adm-clerical':1,
#                           'Transport-moving':2,'Craft-repair':2,'Sales':3,
#                           'Tech-support':3,'Armed-Forces':3,'Protective-serv':3,
#                           'Prof-specialty':4,'Exec-managerial':4}},inplace=True,regex=True)

# x1_test.replace({'relationship':{'Own-child':0,'Other-relative':0,'Unmarried':0,'Not-in-family':1,
#            'Husband':4,'Wife':4}},inplace=True,regex=True)

# x1_test.replace({'workclass':{'Never-worked':0,'Without-pay':0,'\?':1,'Private':2,'State-gov':3,'Self-emp-not-inc':3,
#                         'Local-gov':3,'Federal-gov':4,'Self-emp-inc':5}},inplace=True,regex=True)

# x1_test.replace({'race':{'Other':1,'Black':1,'Amer-Indian-Eskimo':1,'Asian-Pac-Islander':2,'White':2}},inplace=True,regex=True)

# %%
x
# Out:
#        age  workclass  education-num  marital-status  occupation  \
# 0       25          2              7               1           1
# 1       39          2             10               1           0
# 2       35          2             13               0           0
# 3       64          2             11               1           3
# 4       24          2             10               4           2
# ...    ...        ...            ...             ...         ...
# 29300   20          2              9               0           3
# 29301   21          2              9               0           3
# 29302   18          3              6               0           1
# 29303   33          2              7               0           2
# 29304   65          1              9               0           1
#
#        relationship                 race      sex  capital-gain  capital-loss  \
# 0                 1                White     Male             0             0
# ...

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder

encoder = LabelEncoder()
encoder1 = OneHotEncoder(sparse=False)

dummy = x[['sex','race']]
dummy1 = x[['sex','race']]
# x['workclass'] = encoder.fit_transform(x['workclass'])

# x['marital_status'] = encoder.fit_transform(x['marital_status'])
# x['occupation'] = encoder.fit_transform(x['occupation'])
# x['relationship'] = encoder.fit_transform(x['relationship'])
# x['race'] = encoder.fit_transform(x['race'])
pd.get_dummies(x['sex'])
x['capital-gain'] = encoder.fit_transform(x['capital-gain'])
x['capital-loss'] = encoder.fit_transform(x['capital-loss'])
# x['hours-per-week'] = encoder.fit_transform(x['hours-per-week'])
# x['native-country'] = encoder.fit_transform(x['native-country'])

# x['native-country'] = encoder.fit_transform(x['native-country'])
# x.insert(0,'income',y)

x1_test['sex'] = encoder.fit_transform(x1_test['sex'])
x1_test['capital-gain'] = encoder.fit_transform(x1_test['capital-gain'])
x1_test['capital-loss'] = encoder.fit_transform(x1_test['capital-loss'])
# x1_test['hours-per-week'] = encoder.fit_transform(x1_test['hours-per-week'])
# x1_test['native-country'] = encoder.fit_transform(x1_test['native-country'])


# x['workclass'] = encoder.fit_transform(x['workclass'])


# x1_test['marital_status'] = encoder.fit_transform(x1_test['marital_status'])
# x1_test['occupation'] = encoder.fit_transform(x1_test['occupation'])
# x1_test['relationship'] = encoder.fit_transform(x1_test['relationship'])
# x['race'] = encoder.fit_transform(x['race'])
# x1_test['sex'] = encoder.fit_transform(x1_test['sex'])


# x['native-country'] = encoder.fit_transform(x['native-country'])
# x.insert(0,'income',y)

x[['sex_ Female','sex_ Male','race_ Amer-Indian-Eskimo','race_ Asian-Pac-Islander','race_ Black',
   'race_ Other','race_ White']] = pd.get_dummies(dummy)

x1_test[['sex_ Female','sex_ Male','race_ Amer-Indian-Eskimo','race_ Asian-Pac-Islander','race_ Black',
   'race_ Other','race_ White']] = pd.get_dummies(dummy1)
x.drop(['sex','race'],inplace=True,axis=1)
x1_test.drop(['sex','race'],inplace=True,axis=1)
x
# Out:
#        age  workclass  education-num  marital-status  occupation  \
# 0       25          2              7               1           1
# 1       39          2             10               1           0
# 2       35          2             13               0           0
# 3       64          2             11               1           3
# 4       24          2             10               4           2
# ...    ...        ...            ...             ...         ...
# 29300   20          2              9               0           3
# 29301   21          2              9               0           3
# 29302   18          3              6               0           1
# 29303   33          2              7               0           2
# 29304   65          1              9               0           1
#
#        relationship  capital-gain  capital-loss  hours-per-week  sex_ Female  \
# 0                 1             0             0              40            0
# ...

# %%
from sklearn.model_selection import train_test_split #트레인과 test 비율 나눔
from sklearn.model_selection import cross_val_score  # k-fold cross validation
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import Normalizer
from sklearn.preprocessing import RobustScaler

scaler = MinMaxScaler()
scaler2 = StandardScaler()
scaler3 = Normalizer()
scaler4 = RobustScaler()

# edu = scaler.fit_transform(x[['education_num']])
# x['education_num'] = edu

gain = scaler4.fit_transform(x[['capital-gain']])
loss = scaler4.fit_transform(x[['capital-loss']])
gaintest = scaler4.fit_transform(x1_test[['capital-gain']])
losstest = scaler4.fit_transform(x1_test[['capital-loss']])


# x['capital-gain'] = gain
# x['capital-loss'] = loss
# x.value_counts('capital-gain')
# xscaler = scaler3.fit_transform(x)

age = scaler2.fit_transform(x[['age']])
agetest = scaler.fit_transform(x1_test[['age']])
x['age'] = age
x1_test['age'] = agetest

# x.value_counts('capital-loss')
x['capital-gain'] = gain
x['capital-loss'] = loss
x1_test['capital-gain'] = gaintest
x1_test['capital-loss'] = losstest

x
# Out:
#             age  workclass  education-num  marital-status  occupation  \
# 0     -0.993857          2              7               1           1
# 1      0.024799          2             10               1           0
# 2     -0.266246          2             13               0           0
# 3      1.843829          2             11               1           3
# 4     -1.066619          2             10               4           2
# ...         ...        ...            ...             ...         ...
# 29300 -1.357663          2              9               0           3
# 29301 -1.284902          2              9               0           3
# 29302 -1.503186          3              6               0           1
# 29303 -0.411768          2              7               0           2
# 29304  1.916590          1              9               0           1
#
#        relationship  capital-gain  capital-loss  hours-per-week  sex_ Female  \
# ...

# %%
# from sklearn.model_selection import GridSearchCV
# from sklearn.model_selection import cross_val_score, KFold
# from sklearn.model_selection import train_test_split
# from sklearn.ensemble import RandomForestClassifier
# import pandas as pd

x_train,x_test,y_train,y_test = train_test_split(x, y, test_size=0.5,random_state=1)
# x_train = x
# y_train = y

# cv = KFold(n_splits=5, random_state=1, shuffle=True)
# estimator = RandomForestClassifier()
# params = {'n_estimators':[100,200,300,400,450,500], 'criterion':['gini','entropy']}


# gridrf = GridSearchCV(estimator=estimator, param_grid=params,
#                         cv=cv, verbose=-1, n_jobs=-1, refit=True)

# gridrf.fit(x_train, y_train)

# print("Best Estimator:\n", gridrf.best_estimator_)
# print()
# print("Best Params:\n", gridrf.best_params_)
# print()
# print("Best Score:\n", gridrf.best_score_)
# print()

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()
rf.fit(x_train, y_train) #여기서 x_train은 이미 위에서 스케일링함

print(rf.score(x_train, y_train)) #훈련 데이터
print(rf.score(x_test, y_test)) #테스트 데이터
# Out:
# c:\Project\AI_Source\AI_01\venv\lib\site-packages\ipykernel_launcher.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   This is separate from the ipykernel package so we can avoid doing imports until
# 0.9470379470379471
# 0.8353238244728042

# %%
# print(gridrf.score(x_train, y_train))
# print(gridrf.score(x_test, y_test))

# %%
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier(random_state=1,criterion='entropy')
dt.fit(x_train, y_train) #여기서 x_train은 이미 위에서 스케일링함

print(dt.score(x_train, y_train)) #훈련 데이터
print(dt.score(x_test, y_test)) #테스트 데이터
# Out:
# 0.9470379470379471
# 0.8207875520371255

# %%
from sklearn.neighbors import KNeighborsClassifier
kn = KNeighborsClassifier()
kn.fit(x_train, y_train) #여기서 x_train은 이미 위에서 스케일링함

print(kn.score(x_train, y_train)) #훈련 데이터
print(kn.score(x_test, y_test)) #테스트 데이터
# Out:
# c:\Project\AI_Source\AI_01\venv\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# 0.8923696423696423
# 0.8486316795195523

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import StratifiedKFold


rf = RandomForestClassifier(random_state=1,n_estimators = 100,min_samples_split=3,min_samples_leaf=2,max_depth=40)
rf.fit(x_train, y_train) #여기서 x_train은 이미 위에서 스케일링함

print(rf.score(x_train, y_train)) #훈련 데이터
print(rf.score(x_test, y_test)) #테스트 데이터
importances = rf.feature_importances_

print(importances)
# Out:
# c:\Project\AI_Source\AI_01\venv\lib\site-packages\ipykernel_launcher.py:6: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# 0.9201474201474201
# 0.8611205896403467
# [0.1597895  0.03188989 0.14208694 0.1037812  0.09674244 0.15566976
#  0.14294757 0.03934742 0.08857932 0.01230865 0.01105117 0.00100198
#  0.00354858 0.00428591 0.00043489 0.00653479]

# %%
from sklearn.naive_bayes import GaussianNB
gn = GaussianNB()
gn.fit(x_train, y_train) #여기서 x_train은 이미 위에서 스케일링함

print(gn.score(x_train, y_train)) #훈련 데이터
print(gn.score(x_test, y_test)) #테스트 데이터
# Out:
# 0.7831012831012831
# 0.7803862690234081
# c:\Project\AI_Source\AI_01\venv\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
from sklearn.svm import SVC
svc = SVC()
svc.fit(x_train, y_train) #여기서 x_train은 이미 위에서 스케일링함

print(svc.score(x_train, y_train)) #훈련 데이터
print(svc.score(x_test, y_test)) #테스트 데이터
# Out:
# c:\Project\AI_Source\AI_01\venv\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0.8480070980070981
# 0.8478127345935986

# %%
dfsubmit = pd.read_csv('./classification220926/sample_submission.csv')
dfsubmit['income'] = svc.predict(x1_test)
dfsubmit.to_csv('model06_CLA.csv',index=False)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score, KFold
from sklearn.model_selection import train_test_split
from sklearn.ensemble import AdaBoostClassifier
import pandas as pd

cv = KFold(n_splits=5, random_state=1, shuffle=True)
estimator = AdaBoostClassifier()
params = {'random_state':[1],'n_estimators' : [2000],'learning_rate' : [1,1.1,1.2,1.3,1.4,1.5,1.6,1.7]}


gridabc = GridSearchCV(estimator=estimator, param_grid=params,
                        cv=cv, verbose=-1, n_jobs=-1, refit=True)

gridabc.fit(x_train, y_train)

print("Best Estimator:\n", gridabc.best_estimator_)
print()
print("Best Params:\n", gridabc.best_params_)
print()
print("Best Score:\n", gridabc.best_score_)
print()
# Out:
# C:\Users\LUDOBICO\AppData\Roaming\Python\Python37\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Best Estimator:
#  AdaBoostClassifier(learning_rate=1.4, n_estimators=2000, random_state=1)
#
# Best Params:
#  {'learning_rate': 1.4, 'n_estimators': 2000, 'random_state': 1}
#
# Best Score:
#  0.8684099177000562

# %%
from sklearn.ensemble import AdaBoostClassifier


abc = AdaBoostClassifier(random_state=1,
                        n_estimators = 2000,
                         learning_rate = 1)
abc.fit(x_train, y_train) #여기서 x_train은 이미 위에서 스케일링함

print(abc.score(x_train, y_train)) #훈련 데이터
print(abc.score(x_test, y_test)) #테스트 데이터
# Out:
# c:\Project\AI_Source\AI_01\venv\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0.8708026208026208
# 0.8663754862485498

# %%
from sklearn.ensemble import GradientBoostingClassifier
gb = GradientBoostingClassifier(random_state=1,learning_rate=0.1,n_estimators = 2000)
gb.fit(x_train, y_train) #여기서 x_train은 이미 위에서 스케일링함

print(gb.score(x_train, y_train)) #훈련 데이터
print(gb.score(x_test, y_test)) #테스트 데이터
# Out:
# c:\Project\AI_Source\AI_01\venv\lib\site-packages\sklearn\ensemble\_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0.8943488943488943
# 0.8630997065447349

# %%
dfsubmit = pd.read_csv('./classification220926/sample_submission.csv')

# %%
dfsubmit['income'] = gb.predict(x1_test)
dfsubmit.to_csv('model06_CLA_86.csv',index=False)

# %%
from sklearn.linear_model import RidgeClassifier
rc = RidgeClassifier(random_state=1)
rc.fit(x_train, y_train) #여기서 x_train은 이미 위에서 스케일링함

print(rc.score(x_train, y_train)) #훈련 데이터
print(rc.score(x_test, y_test)) #테스트 데이터
# Out:
# 0.8402265902265902
# 0.8444004640687913
# c:\Project\AI_Source\AI_01\venv\lib\site-packages\sklearn\linear_model\_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, ExtraTreesClassifier, BaggingClassifier, GradientBoostingClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegressionCV
from sklearn.ensemble import VotingClassifier

models = [
    ('ada', AdaBoostClassifier()),
    ('bc', BaggingClassifier()),
    ('etc',ExtraTreesClassifier()),
    ('gbc', GradientBoostingClassifier()),
    ('rfc', RandomForestClassifier()),
    ('knn', KNeighborsClassifier()),
    ('svc', SVC(probability=True)),
    ('dtc', DecisionTreeClassifier()),
    ('lr', LogisticRegressionCV()),
]

soft_vote  = VotingClassifier(models, voting='soft')
soft_vote.fit(x_train, y_train)

print(soft_vote.score(x_train, y_train)) #훈련 데이터
print(soft_vote.score(x_test, y_test)) #테스트 데이터
# Out:
# c:\Project\AI_Source\AI_01\venv\lib\site-packages\sklearn\preprocessing\_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Project\AI_Source\AI_01\venv\lib\site-packages\sklearn\preprocessing\_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Project\AI_Source\AI_01\venv\lib\site-packages\sklearn\linear_model\_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...
