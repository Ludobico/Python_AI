# %%
import pandas as pd
import json

# %%
with open('BOHE210000025292.json', 'rt', encoding='UTF-8') as json_file:
    json_load = json.load(json_file)
json_load.SJML
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_35660\327032194.py in <module>
#       1 with open('BOHE210000025292.json', 'rt', encoding='UTF-8') as json_file:
#       2     json_load = json.load(json_file)
# ----> 3 json_load.SJML
#
# AttributeError: 'dict' object has no attribute 'SJML'

# %%
df = pd.read_json('BOHE210000025292.json')
dj = df.SJML.text
dflist = []

for i in range(len(dj)):
    dflist.append(dj[i]['content'])

dj2 = pd.DataFrame(dflist)
dj2.sample(50)
# Out:
#                                                      0
# 108             준디한테 제 심장을 뚜드려 맞아서 터져버렸습니다 책임지고 결혼해주세요
# 165                                        진짜 저건희석 무조건
# 164                                        준디 영원히팬할꺼에요
# 52                                          앗 저도 사랑합니다
# 21                                      진짜 준디 (비속어)사랑해
# 135                                            항상 고마워요
# 44                                     우리 준댕이 너무너무 고마워
# 102                                            항상 고마워요
# 236                                         주희 항상 고마워요
# 117                     넘 귀엽잖아요 취하능 준디 근데 봐도 진짜 취하는 느낌
# 200                                     우리 준댕이 항상 고마워요
# 85                                         다히 항상 사랑합디다
# 61   아니 이건 내가 젤 조아하는 술 먹는 영상이잖아 이번 영상을 통해 다시 한 번 느꼈...
# 128                  준디 흐잉 오빠 팬미팅 소식 들려오면 바로 달려갈게요 존버중
# 24                                      갑자기 취하는거 짱신기해여
# 98                             소주 못먹겠어요항상 고마워요 조심히 먹을게
# ...
